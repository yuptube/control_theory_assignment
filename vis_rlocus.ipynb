# %% [markdown]
# ## interactive rendition for making the root locus plot

# %% [markdown]
# ### import modules

# %%
import numpy as np
import matplotlib.pyplot as plt
import control as ctrl
import ipywidgets as widgets
from IPython.display import display
from root_locus_plot import PlotRootLocus

# %% [markdown]
# ### Set up for The equation

# %%
K = 600 # K<143
kt = 0.0717
kt_max = 0.305386 
G=ctrl.TransferFunction([1,3], [1,4, 5])
D=ctrl.TransferFunction([K], [1, 10])
I=ctrl.TransferFunction([1], [1, 0])

# %% [markdown]
# ### build the class

# %%
# for the 1 loop system , remove the Kt term 
system = PlotRootLocus(G=G, D=D, I=I, K=K, Kt=kt)

# %% [markdown]
# ## Plotting graph for root locus and step response

# %%
system.plot_root_locus()
system.plot_step_response()
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %% [markdown]
# ## Create a plot for maximun damping factor

# %%
# Compute and display max damping factor

max_zeta , K_T , omega_n =system.compute_max_damping_factor()
print(f"max zeta is {max_zeta} , K_T is {K_T} , omega_n is {omega_n}"   )

# %% [markdown]
# ## plot bode and transfer function after gain

# %%
system.vis_max_zeta_plot_bode()
system.plot_transfer_function_after_feedback()
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
